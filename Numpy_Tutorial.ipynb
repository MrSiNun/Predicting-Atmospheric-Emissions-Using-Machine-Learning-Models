# %% [markdown]
# # Numpy as NP

# %% [markdown]
# - Arreys Library that Pandas and all the Data Science uses.
# - When you create a number, you are also attaching bunch of other things in python as it is object oriented. But with Numpy Array, it shrinks.

# %% [markdown]
# ![image.png](attachment:7684844a-820d-4872-8505-a53651efb6ef.png)

# %%
import numpy as np

# %%
np.array([1, 2, 3, 4])

# %%
a = np.array([1, 2, 3, 4])

# %%
b = np.array([.5, 1, 1.5, 2])

# %%
b

# %%
a[0], b[3]

# %%
a[1:-1]

# %%
b[[1,2,1]]

# %%
a.dtype #d for default, type for type

# %%
b.dtype

# %%
import numpy as np
np.array([1, 5.56, 3.55, 4], dtype=float)

# %%
d=np.array(['a', 'l', 't'])

# %%
d.dtype #the result will be 'unico object'

# %% [markdown]
# ........^\
# ........|
# - Usually DO NOT USE Numpy for Objects like the one above

# %% [markdown]
# ## Matrix by Nummpy

# %%
A = np.array([[1,2,3], [4,5,6]])

# %%
A
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
A.shape
# Out:
# (2, 3)

# %%
A.size

# %%
A.ndim

# %%
import numpy as np
B = np.array([[1,2,3], [4,5,6], [4,4,4]])

# %%
B.size
# Out:
# 9

# %%
B.shape
# Out:
# (3, 3)

# %%
B.ndim
# Out:
# 2

# %%
C = np.array([[[1,2,3],[2,2,2]], [[1,2,3],[2,2,2]], [[1,2,3],[2,2,2]]])

# %%
C.size
# Out:
# 18

# %%
C.shape
# Out:
# (3, 2, 3)

# %%
C.ndim
# Out:
# 3

# %%
C[1]
# Out:
# array([[1, 2, 3],
#        [2, 2, 2]])

# %%
C[1:3]
# Out:
# array([[[1, 2, 3],
#         [2, 2, 2]],
#
#        [[1, 2, 3],
#         [2, 2, 2]]])

# %%
C[:, 0:2] #C[ ROW , COLOUM ]
# Out:
# array([[[1, 2, 3],
#         [2, 2, 2]],
#
#        [[1, 2, 3],
#         [2, 2, 2]],
#
#        [[1, 2, 3],
#         [2, 2, 2]]])
