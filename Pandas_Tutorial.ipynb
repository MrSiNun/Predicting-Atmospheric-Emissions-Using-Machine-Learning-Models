# %% [markdown]
# # PANDAS as PD

# %% [markdown]
# ## Part I

# %% [markdown]
# - Has only 2 type of **DATA STRUCTURES**:
# 1. **Series**
# 2. **DataFrames**

# %% [markdown]
# - Series is ndim = 1 Coloumn Vector #One Dimentional
# - DataFrame combinations of coloum vectors ( Series ) tables.

# %% [markdown]
# ![image.png](attachment:61e758f9-8ddb-477b-affd-213e57d0d090.png)

# %%
import pandas as pd

# %%
import numpy as np

# %%
isimler = (['Avery Bradley', 'Jhon Holland', 'Jonas Jerebko'])

# %%
my_series = pd.Series(isimler, name='Ad Soyad')

# %%
my_series
# Out:
# 0    Avery Bradley
# 1     Jhon Holland
# 2    Jonas Jerebko
# Name: Ad Soyad, dtype: object

# %%
my_series[0:1]
# Out:
# 0    Avery Bradley
# Name: Ad Soyad, dtype: object

# %%
df = pd.read_csv('heart_disease_uci.csv')

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
age = pd.Series(isimler, name='age')

# %%
age
# Out:
# 0    Avery Bradley
# 1     Jhon Holland
# 2    Jonas Jerebko
# Name: age, dtype: object

# %%
age = pd.Series(df['age'])

# %%
age.head()
# Out:
# 0    63
# 1    67
# 2    67
# 3    37
# 4    41
# Name: age, dtype: int64

# %%
import matplotlib as ptl

# %%
data = df[['age','sex']]

# %%
data
# Out:
#      age     sex
# 0     63    Male
# 1     67    Male
# 2     67    Male
# 3     37    Male
# 4     41  Female
# ..   ...     ...
# 915   54  Female
# 916   62    Male
# 917   55    Male
# 918   58    Male
# 919   62    Male
#
# [920 rows x 2 columns]

# %% [markdown]
# ## Part II

# %%
import pandas as pd

# %%
import numpy as np

# %%
series1 = pd.Series([1, 2, 3, 4, 5])

# %%
series1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series2 = pd.Series([2, 2, 3, 4, 5]) #Series is a class and have to start with CAPPITAL LETTER

# %%
series2
# Out:
# 0    2
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data = np.array([['series1', 'series2'], ['series2', 'series2']])

# %%
data
# Out:
# array([['series1', 'series2'],
#        ['series2', 'series2']], dtype='<U7')

# %%
series1[2]
# Out:
# 3

# %%
data.size
# Out:
# 4

# %%
data.shape
# Out:
# (2, 2)

# %%
#df = pd.df('data') #WRONG WAY

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#          0        1
# 0  series1  series2
# 1  series2  series2

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ## series.Head() method
#
# which retrieves first 5 results

# %% [markdown]
# # A NICE EXAMPLE OF GENERATING A SERIES

# %%
dt = np.array([1,1.5,2,2.5,3.14])

# %%
series = pd.Series([1,1.5,2,2.5,3.14], index=['first', 'second', 'third','fourth', 'fifth'], dtype=np.float64, name='sira deger matrisi')

# %% [markdown]
# ## Series( den sonra coloum gelir, yani df['age'] gibi. ya age in degerleri manuel girilir ya da de['age'] seklide. Her coloumn tek tek girilecegi icin df['age', 'sex'] de olabilirdi.

# %%
series
# Out:
# first     1.00
# second    1.50
# third     2.00
# fourth    2.50
# fifth     3.14
# Name: sira deger matrisi, dtype: float64

# %% [markdown]
# ### VALUES

# %%
series.values
# Out:
# array([1.  , 1.5 , 2.  , 2.5 , 3.14])

# %%
series.values[0:2]
# Out:
# array([1. , 1.5])

# %% [markdown]
# ## TYPE

# %%
series.dtype
# Out:
# dtype('float64')

# %%
type(series.values)
# Out:
# numpy.ndarray

# %% [markdown]
# ## INDEX

# %%
series.index
# Out:
# Index(['first', 'second', 'third', 'fourth', 'fifth'], dtype='object')

# %% [markdown]
# ## N DIMENTION

# %%
series.ndim
# Out:
# 1

# %%
series.shape
# Out:
# (5,)

# %%
series.size
# Out:
# 5

# %% [markdown]
# ### EXAMPLE THE GROUP OF SEVEN

# %%
g7 = np.array(['Canada', 'France','Germany','Italy', 'Japan', 'UK', 'USA'])

# %%
g7
# Out:
# array(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'UK', 'USA'],
#       dtype='<U7')

# %%
pop = np.array([38.93, 67.97, 83.8, 58.94, 125.12, 66.97, 333.29])

# %%
pop
# Out:
# array([ 38.93,  67.97,  83.8 ,  58.94, 125.12,  66.97, 333.29])

# %%
#In Millions Polupations

g7_pop = pd.Series([38.93, 67.97, 83.8, 58.94, 125.12, 66.97, 333.29])

# %%
g7_pop
# Out:
# 0     38.93
# 1     67.97
# 2     83.80
# 3     58.94
# 4    125.12
# 5     66.97
# 6    333.29
# dtype: float64

# %%
g7_pop
# Out:
# 0     38.93
# 1     67.97
# 2     83.80
# 3     58.94
# 4    125.12
# 5     66.97
# 6    333.29
# dtype: float64

# %% [markdown]
# # __INDEX__ method 1 series.index['index column names'] USE THIS ONE!!!!!
#
# gy_pop.index = ['Canada', 'France', 'Italy', 'Japan', 'UK', 'USA']

# %%
g7_pop.index= ['Canada', 'France','Germany','Italy', 'Japan', 'UK', 'USA']

# %% [markdown]
# # __INDEX__ method 2 gy_pop=pd.Series(index  =  ['index column names']) ''='' HER ZAMAN VAR
#
# g7_pop = pd.Series(pop, index=['Canada', 'France', 'Italy', 'Japan', 'UK', 'USA'])
#
# g7_pop = pd.Series([38.93, 67.97, 83.8, 58.94, 125.12, 66.97, 333.29], index=['Canada', 'France', 'Germany', 'Italy', 'Japan', 'UK', 'USA'])

# %%
g7_pop
# Out:
# Canada      38.93
# France      67.97
# Germany     83.80
# Italy       58.94
# Japan      125.12
# UK          66.97
# USA        333.29
# dtype: float64

# %%
g7_pop = pd.Series([38.93, 67.97, 83.8, 58.94, 125.12, 66.97, 333.29], index=['Canada', 'France', 'Germany', 'Italy', 'Japan', 'UK', 'USA'])

# %%
g7_pop = pd.Series([38.93, 67.97, 83.8, 58.94, 125.12, 66.97, 333.29], index=['Canada', 'France', 'Germany', 'Italy', 'Japan', 'UK', 'USA'])

# %%
g7_pop
# Out:
# Canada      38.93
# France      67.97
# Germany     83.80
# Italy       58.94
# Japan      125.12
# UK          66.97
# USA        333.29
# dtype: float64

# %%
g7_pop.index= ['Canada', 'France','Germany','Italy', 'Japan', 'UK', 'USA']

# %%
g7_pop
# Out:
# Canada      38.93
# France      67.97
# Germany     83.80
# Italy       58.94
# Japan      125.12
# UK          66.97
# USA        333.29
# dtype: float64

# %% [markdown]
# # __INDEX__ method 3 with the help of __Ordered Data Dictionary__

# %%
data_dic = { 
    'Canada' : 38.93,
    'France' : 67.97}

g2_pop = pd.Series(data_dic, name='g2_pop')

# %%
g2_pop
# Out:
# Canada    38.93
# France    67.97
# Name: g2_pop, dtype: float64

# %% [markdown]
# # __INDEX__ method 4 Step by Step

# %%
values = [35000, 50000]
indexes = ['Danmark', 'Findland']

g_ulke=pd.Series(values, index= indexes, name='SONULKE')

# %%
g_ulke
# Out:
# Danmark     35000
# Findland    50000
# Name: SONULKE, dtype: int64

# %% [markdown]
# # Read CSV files

# %%
df
# Out:
#          0        1
# 0  series1  series2
# 1  series2  series2

# %%
df1=pd.read_csv('btc-market-price.csv', header=None, na_values=[''])

# %%
df1
# Out:
#                        0            1
# 0    2017-04-02 00:00:00  1099.169125
# 1    2017-04-03 00:00:00  1141.813000
# 2    2017-04-04 00:00:00  1141.600363
# 3    2017-04-05 00:00:00  1133.079314
# 4    2017-04-06 00:00:00  1196.307937
# ..                   ...          ...
# 360  2018-03-28 00:00:00  7960.380000
# 361  2018-03-29 00:00:00  7172.280000
# 362  2018-03-30 00:00:00  6882.531667
# 363  2018-03-31 00:00:00  6935.480000
# 364  2018-04-01 00:00:00  6794.105000
#
# [365 rows x 2 columns]

# %%
# WRONG df1.head

# %%
df1.head()
# Out:
#                      0            1
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
df1.columns=['Timestamp', 'Price']

# %%
df1.head()
# Out:
#              Timestamp        Price
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
df1.dtypes
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %%
df1['Timestamp']=pd.to_datetime(df1['Timestamp'])

# %%
df1.dtypes
# Out:
# Timestamp    datetime64[ns]
# Price               float64
# dtype: object

# %%
df1.head()
# Out:
#    Timestamp        Price
# 0 2017-04-02  1099.169125
# 1 2017-04-03  1141.813000
# 2 2017-04-04  1141.600363
# 3 2017-04-05  1133.079314
# 4 2017-04-06  1196.307937

# %%
df1.set_index('Timestamp', inplace=True)

# %%
df1.head()
# Out:
#                   Price
# Timestamp
# 2017-04-02  1099.169125
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937

# %%
import matplotlib as plt

# %%
df1.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Timestamp'>

# %% [markdown]
# # JSON, SQL read methods will be checked on https://youtu.be/fag1oWtskwU?si=Lhq5gju3l-5oB42n
